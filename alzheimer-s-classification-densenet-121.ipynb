# %% [markdown]
# ### IMPORT LIBRARIES

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn
import skimage.io
import os 
import tqdm
import glob
import tensorflow 

from tqdm import tqdm
from sklearn.utils import shuffle
from sklearn import metrics
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split

from skimage.io import imread, imshow
from skimage.transform import resize
from skimage.color import grey2rgb

import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import InputLayer, BatchNormalization, Dropout, Flatten, Dense, Activation, MaxPool2D, Conv2D
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.applications.vgg16 import VGG16 # VGG16
from tensorflow.keras.applications.vgg19 import VGG19 # VGG19
from tensorflow.keras.applications.resnet50 import ResNet50 # ResNet50
from tensorflow.keras.applications.xception import Xception # Xception
from tensorflow.keras.applications.mobilenet import MobileNet # MobileNet
from tensorflow.keras.applications.nasnet import NASNetMobile # NASNetMobile
from tensorflow.keras.applications.densenet import DenseNet169 # DenseNet169
from tensorflow.keras.applications.densenet import DenseNet121 # DenseNet121
from tensorflow.keras.applications.mobilenet_v2 import MobileNetV2 # MobileNetV2
from tensorflow.keras.applications.inception_v3 import InceptionV3
from tensorflow.keras.utils import to_categorical
from keras import optimizers

from keras.callbacks import Callback,ModelCheckpoint
from keras.models import Sequential,load_model
from keras.layers import Dense, Dropout
from keras.wrappers.scikit_learn import KerasClassifier
import keras.backend as K

#import tensorflow_addons as tfa
#from tensorflow.keras.metrics import Metric
#from tensorflow_addons.utils.types import AcceptableDTypes, FloatTensorLike
from typeguard import typechecked
from typing import Optional

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE

# %%
train_datagen = ImageDataGenerator(rescale = 1./255,
                                   validation_split = 0.2,
                                  
        rotation_range=5,
        width_shift_range=0.2,
        height_shift_range=0.2,
        shear_range=0.2,
        #zoom_range=0.2,
        horizontal_flip=True,
        vertical_flip=True,
        fill_mode='nearest')

valid_datagen = ImageDataGenerator(rescale = 1./255,
                                  validation_split = 0.2)

test_datagen  = ImageDataGenerator(rescale = 1./255
                                  )

# %%
#train_dataset = tf.keras.preprocessing.image_dataset_from_directory('../input/alzheimers-dataset-4-class-of-images/Alzheimer_s Dataset/train',
#                                                                        validation_split=0.2,
#                                                                        subset="training",
#                                                                        shuffle=False,
#                                                                        image_size=(224,224),
#                                                                        batch_size=32,
#                                                                        )

train_dataset  = train_datagen.flow_from_directory(directory = '../input/alzheimers-dataset-4-class-of-images/Alzheimer_s Dataset/train',
                                                   target_size = (224,224),
                                                   class_mode = 'categorical',
                                                   subset = 'training',
                                                   batch_size = 32)
# Out:
# Found 4098 images belonging to 4 classes.

# %%
#valid_dataset = tf.keras.preprocessing.image_dataset_from_directory('../input/alzheimers-dataset-4-class-of-images/Alzheimer_s Dataset/train',
#                                                                        validation_split=0.2,
#                                                                        subset="validation",
#                                                                        shuffle=False,
#                                                                        image_size=(224,224),
#                                                                        batch_size=32,
#                                                                        )
valid_dataset = valid_datagen.flow_from_directory(directory = '../input/alzheimers-dataset-4-class-of-images/Alzheimer_s Dataset/train',
                                                  target_size = (224,224),
                                                  class_mode = 'categorical',
                                                  subset = 'validation',
                                                  batch_size = 32)
# Out:
# Found 1023 images belonging to 4 classes.

# %%
#test_dataset = tf.keras.preprocessing.image_dataset_from_directory("../input/alzheimers-dataset-4-class-of-images/Alzheimer_s Dataset/test",
##                                                            shuffle=False,
#                                                            image_size=(224,224),
#                                                            batch_size=32,
#)

test_dataset = test_datagen.flow_from_directory(directory = '../input/alzheimers-dataset-4-class-of-images/Alzheimer_s Dataset/test',
                                                  target_size = (224,224),
                                                  class_mode = 'categorical',
                                                  batch_size = 32)
# Out:
# Found 1279 images belonging to 4 classes.

# %% [markdown]
# ## feature preprocessing and label encoding.

# %% [markdown]
# ### MODEL BUILDING

# %%
base_model = DenseNet121(input_shape=(224,224,3), 
                   include_top=False,
                   weights="imagenet")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29089792/29084464 [==============================] - 0s 0us/step

# %%
# Freezing Layers

for layer in base_model.layers:
    layer.trainable=False

# %%
# Building Model

model=Sequential()
model.add(base_model)
model.add(Dropout(0.5))
model.add(Flatten())
model.add(BatchNormalization())
model.add(Dense(64,kernel_initializer='he_uniform'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(64,kernel_initializer='he_uniform'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(64,kernel_initializer='he_uniform'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(32,kernel_initializer='he_uniform'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(32,kernel_initializer='he_uniform'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dense(4,activation='softmax'))

# %%
# Model Summary

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# densenet121 (Functional)     (None, 7, 7, 1024)        7037504
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 7, 7, 1024)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 50176)             0
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 50176)             200704
# _________________________________________________________________
# dense_6 (Dense)              (None, 64)                3211328
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 64)                256
# _________________________________________________________________
# activation_5 (Activation)    (None, 64)                0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_7 (Dense)              (None, 64)                4160
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 64)                256
# _________________________________________________________________
# activation_6 (Activation)    (None, 64)                0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_8 (Dense)              (None, 64)                4160
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 64)                256
# _________________________________________________________________
# activation_7 (Activation)    (None, 64)                0
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_9 (Dense)              (None, 32)                2080
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 32)                128
# _________________________________________________________________
# activation_8 (Activation)    (None, 32)                0
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_10 (Dense)             (None, 32)                1056
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 32)                128
# _________________________________________________________________
# activation_9 (Activation)    (None, 32)                0
# _________________________________________________________________
# dense_11 (Dense)             (None, 4)                 132
# =================================================================
# Total params: 10,462,148
# Trainable params: 3,323,780
# Non-trainable params: 7,138,368
# _________________________________________________________________

# %%
def f1_score(y_true, y_pred): #taken from old keras source code
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.epsilon())
    return f1_val

# %%
METRICS = [
      tf.keras.metrics.BinaryAccuracy(name='accuracy'),
      tf.keras.metrics.Precision(name='precision'),
      tf.keras.metrics.Recall(name='recall'),  
      tf.keras.metrics.AUC(name='auc'),
        f1_score,
]

# %%
def exponential_decay(lr0, s):
    def exponential_decay_fn(epoch):
        return lr0 * 0.1 **(epoch / s)
    return exponential_decay_fn

exponential_decay_fn = exponential_decay(0.01, 5) # when i run it for 50 epochs

lr_scheduler = tf.keras.callbacks.LearningRateScheduler(exponential_decay_fn)

# %%
model.compile(optimizer='rmsprop', loss='categorical_crossentropy',metrics=METRICS)

# %%
history=model.fit(train_dataset,
                        validation_data=valid_dataset,
                        epochs = 20,
                        verbose = 1,
                         callbacks=lr_scheduler)
# Out:
# Epoch 1/20
# 129/129 [==============================] - 56s 431ms/step - loss: 1.0941 - accuracy: 0.7414 - precision: 0.4641 - recall: 0.2223 - auc: 0.7655 - f1_score: 0.2897 - val_loss: 1.3235 - val_accuracy: 0.7720 - val_precision: 0.5500 - val_recall: 0.4839 - val_auc: 0.7978 - val_f1_score: 0.5143
# Epoch 2/20
# 129/129 [==============================] - 52s 403ms/step - loss: 1.0432 - accuracy: 0.7575 - precision: 0.5364 - recall: 0.2211 - auc: 0.7851 - f1_score: 0.3079 - val_loss: 1.0560 - val_accuracy: 0.7859 - val_precision: 0.6567 - val_recall: 0.3011 - val_auc: 0.8071 - val_f1_score: 0.4094
# Epoch 3/20
# 129/129 [==============================] - 53s 413ms/step - loss: 1.0208 - accuracy: 0.7696 - precision: 0.6148 - recall: 0.2103 - auc: 0.7953 - f1_score: 0.3112 - val_loss: 0.9884 - val_accuracy: 0.7874 - val_precision: 0.7297 - val_recall: 0.2375 - val_auc: 0.8211 - val_f1_score: 0.3536
# Epoch 4/20
# 129/129 [==============================] - 53s 413ms/step - loss: 1.0015 - accuracy: 0.7776 - precision: 0.6657 - recall: 0.2216 - auc: 0.8003 - f1_score: 0.3337 - val_loss: 0.9749 - val_accuracy: 0.7947 - val_precision: 0.7282 - val_recall: 0.2854 - val_auc: 0.8313 - val_f1_score: 0.4064
# Epoch 5/20
# 129/129 [==============================] - 53s 409ms/step - loss: 0.9847 - accuracy: 0.7812 - precision: 0.7000 - recall: 0.2186 - auc: 0.8053 - f1_score: 0.3326 - val_loss: 0.9666 - val_accuracy: 0.7876 - val_precision: 0.8235 - val_recall: 0.1916 - val_auc: 0.8260 - val_f1_score: 0.3073
# Epoch 6/20
# 129/129 [==============================] - 52s 406ms/step - loss: 0.9759 - accuracy: 0.7840 - precision: 0.7101 - recall: 0.2301 - auc: 0.8123 - f1_score: 0.3487 - val_loss: 0.9659 - val_accuracy: 0.7881 - val_precision: 0.8250 - val_recall: 0.1935 - val_auc: 0.8236 - val_f1_score: 0.3068
# Epoch 7/20
# 129/129 [==============================] - 52s 404ms/step - loss: 0.9710 - accuracy: 0.7871 - precision: 0.7331 - recall: 0.2333 - auc: 0.8146 - f1_score: 0.3555 - val_loss: 0.9647 - val_accuracy: 0.7857 - val_precision: 0.8174 - val_recall: 0.1838 - val_auc: 0.8221 - val_f1_score: 0.2968
# Epoch 8/20
# 129/129 [==============================] - 52s 402ms/step - loss: 0.9729 - accuracy: 0.7857 - precision: 0.7287 - recall: 0.2274 - auc: 0.8117 - f1_score: 0.3479 - val_loss: 0.9657 - val_accuracy: 0.7857 - val_precision: 0.8174 - val_recall: 0.1838 - val_auc: 0.8210 - val_f1_score: 0.2957
# Epoch 9/20
# 129/129 [==============================] - 53s 411ms/step - loss: 0.9599 - accuracy: 0.7875 - precision: 0.7427 - recall: 0.2296 - auc: 0.8177 - f1_score: 0.3475 - val_loss: 0.9613 - val_accuracy: 0.7871 - val_precision: 0.8140 - val_recall: 0.1926 - val_auc: 0.8245 - val_f1_score: 0.3064
# Epoch 10/20
# 129/129 [==============================] - 53s 409ms/step - loss: 0.9690 - accuracy: 0.7863 - precision: 0.7344 - recall: 0.2274 - auc: 0.8149 - f1_score: 0.3512 - val_loss: 0.9597 - val_accuracy: 0.7881 - val_precision: 0.8171 - val_recall: 0.1965 - val_auc: 0.8234 - val_f1_score: 0.3127
# Epoch 11/20
# 129/129 [==============================] - 52s 406ms/step - loss: 0.9607 - accuracy: 0.7886 - precision: 0.7530 - recall: 0.2299 - auc: 0.8190 - f1_score: 0.3554 - val_loss: 0.9593 - val_accuracy: 0.7884 - val_precision: 0.8178 - val_recall: 0.1975 - val_auc: 0.8233 - val_f1_score: 0.3151
# Epoch 12/20
# 129/129 [==============================] - 52s 406ms/step - loss: 0.9614 - accuracy: 0.7888 - precision: 0.7454 - recall: 0.2357 - auc: 0.8180 - f1_score: 0.3542 - val_loss: 0.9591 - val_accuracy: 0.7881 - val_precision: 0.8171 - val_recall: 0.1965 - val_auc: 0.8242 - val_f1_score: 0.3137
# Epoch 13/20
# 129/129 [==============================] - 52s 404ms/step - loss: 0.9659 - accuracy: 0.7871 - precision: 0.7436 - recall: 0.2265 - auc: 0.8174 - f1_score: 0.3436 - val_loss: 0.9616 - val_accuracy: 0.7874 - val_precision: 0.8148 - val_recall: 0.1935 - val_auc: 0.8225 - val_f1_score: 0.3106
# Epoch 14/20
# 129/129 [==============================] - 51s 398ms/step - loss: 0.9711 - accuracy: 0.7861 - precision: 0.7331 - recall: 0.2272 - auc: 0.8143 - f1_score: 0.3483 - val_loss: 0.9597 - val_accuracy: 0.7881 - val_precision: 0.8171 - val_recall: 0.1965 - val_auc: 0.8235 - val_f1_score: 0.3131
# Epoch 15/20
# 129/129 [==============================] - 52s 401ms/step - loss: 0.9610 - accuracy: 0.7879 - precision: 0.7437 - recall: 0.2316 - auc: 0.8186 - f1_score: 0.3529 - val_loss: 0.9610 - val_accuracy: 0.7874 - val_precision: 0.8148 - val_recall: 0.1935 - val_auc: 0.8229 - val_f1_score: 0.3082
# Epoch 16/20
# 129/129 [==============================] - 52s 401ms/step - loss: 0.9632 - accuracy: 0.7870 - precision: 0.7312 - recall: 0.2343 - auc: 0.8140 - f1_score: 0.3559 - val_loss: 0.9584 - val_accuracy: 0.7889 - val_precision: 0.8167 - val_recall: 0.2004 - val_auc: 0.8235 - val_f1_score: 0.3178
# Epoch 17/20
# 129/129 [==============================] - 51s 399ms/step - loss: 0.9697 - accuracy: 0.7881 - precision: 0.7413 - recall: 0.2343 - auc: 0.8167 - f1_score: 0.3522 - val_loss: 0.9571 - val_accuracy: 0.7893 - val_precision: 0.8132 - val_recall: 0.2043 - val_auc: 0.8240 - val_f1_score: 0.3238
# Epoch 18/20
# 129/129 [==============================] - 53s 412ms/step - loss: 0.9604 - accuracy: 0.7903 - precision: 0.7498 - recall: 0.2421 - auc: 0.8189 - f1_score: 0.3622 - val_loss: 0.9564 - val_accuracy: 0.7901 - val_precision: 0.8154 - val_recall: 0.2072 - val_auc: 0.8246 - val_f1_score: 0.3269
# Epoch 19/20
# 129/129 [==============================] - 53s 410ms/step - loss: 0.9651 - accuracy: 0.7856 - precision: 0.7271 - recall: 0.2282 - auc: 0.8137 - f1_score: 0.3484 - val_loss: 0.9593 - val_accuracy: 0.7889 - val_precision: 0.8167 - val_recall: 0.2004 - val_auc: 0.8231 - val_f1_score: 0.3173
# Epoch 20/20
# 129/129 [==============================] - 52s 406ms/step - loss: 0.9769 - accuracy: 0.7859 - precision: 0.7253 - recall: 0.2313 - auc: 0.8125 - f1_score: 0.3473 - val_loss: 0.9572 - val_accuracy: 0.7891 - val_precision: 0.8125 - val_recall: 0.2033 - val_auc: 0.8253 - val_f1_score: 0.3204

# %%
#%% PLOTTING RESULTS (Train vs Validation FOLDER 1)

def Train_Val_Plot(acc,val_acc,loss,val_loss,auc,val_auc,precision,val_precision,f1,val_f1):
    
    fig, (ax1, ax2,ax3,ax4,ax5) = plt.subplots(1,5, figsize= (20,5))
    fig.suptitle(" MODEL'S METRICS VISUALIZATION ")

    ax1.plot(range(1, len(acc) + 1), acc)
    ax1.plot(range(1, len(val_acc) + 1), val_acc)
    ax1.set_title('History of Accuracy')
    ax1.set_xlabel('Epochs')
    ax1.set_ylabel('Accuracy')
    ax1.legend(['training', 'validation'])


    ax2.plot(range(1, len(loss) + 1), loss)
    ax2.plot(range(1, len(val_loss) + 1), val_loss)
    ax2.set_title('History of Loss')
    ax2.set_xlabel('Epochs')
    ax2.set_ylabel('Loss')
    ax2.legend(['training', 'validation'])
    
    ax3.plot(range(1, len(auc) + 1), auc)
    ax3.plot(range(1, len(val_auc) + 1), val_auc)
    ax3.set_title('History of AUC')
    ax3.set_xlabel('Epochs')
    ax3.set_ylabel('AUC')
    ax3.legend(['training', 'validation'])
    
    ax4.plot(range(1, len(precision) + 1), precision)
    ax4.plot(range(1, len(val_precision) + 1), val_precision)
    ax4.set_title('History of Precision')
    ax4.set_xlabel('Epochs')
    ax4.set_ylabel('Precision')
    ax4.legend(['training', 'validation'])
    
    ax5.plot(range(1, len(f1) + 1), f1)
    ax5.plot(range(1, len(val_f1) + 1), val_f1)
    ax5.set_title('History of F1-score')
    ax5.set_xlabel('Epochs')
    ax5.set_ylabel('F1 score')
    ax5.legend(['training', 'validation'])


    plt.show()
    

Train_Val_Plot(history.history['accuracy'],history.history['val_accuracy'],
               history.history['loss'],history.history['val_loss'],
               history.history['auc'],history.history['val_auc'],
               history.history['precision'],history.history['val_precision'],
               history.history['f1_score'],history.history['val_f1_score']
              )

# %%
scores = model.evaluate_generator(test_dataset)

# %%
print("Accuracy = ", scores[1])
print("Precision = ", scores[2])
print("Recall = ", scores[3])
print("AUC = ", scores[4])
print("F1_score = ", scores[5])
# Out:
# Accuracy =  0.7900703549385071
# Precision =  0.7223427295684814
# Recall =  0.26035964488983154
# AUC =  0.825272262096405
# F1_score =  0.3778386414051056
